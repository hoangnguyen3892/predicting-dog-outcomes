# %%
import numpy as np
import pandas as pd
import pickle
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.tools.eval_measures import aic
from patsy.contrasts import Treatment
from sklearn.metrics import classification_report, accuracy_score,log_loss, precision_recall_fscore_support, confusion_matrix
from sklearn import metrics
from numpy import linspace, bincount, hstack, cumsum
from matplotlib.pyplot import subplots, show
import itertools
import matplotlib.pyplot as plt
from matplotlib import cm
#import statsmodels.discrete.discrete_model as st

# %% [markdown]
# build function to find optimal n_estimators
# note: if learning_rate, reg_alpha, reg_lambda are not set
# xgboost will use default values from https://github.com/dmlc/xgboost/blob/master/doc/parameter.md
# e.g. eta = 0.3 instead of 0.1
# if they are set, eta, alpha, lambda will be overwritten
# the best n_estimators is Name + 1

# %%
# load data
with open("preprocessed_data.pkl", "rb") as f:
    train_logit = pickle.load(f)
    test_data_logit = pickle.load(f)
    test_label_logit = pickle.load(f)
    train_data = pickle.load(f)
    train_label = pickle.load(f)
    test_data = pickle.load(f)
    test_label = pickle.load(f)
    label_list = pickle.load(f)

# %%
label_list
# Out:
# ['Adoption', 'Euthanasia', 'Return to Owner', 'Transfer']

# %%
list(train_logit.columns.values)
# Out:
# ['OutcomeType',
#  'Age',
#  'Size',
#  'HasName',
#  'TimeofDay',
#  'WeekDay',
#  'IsIntact',
#  'Sex',
#  'PureMixedHybrid',
#  'Group',
#  'IsMixColor']

# %%
model = smf.mnlogit('OutcomeType ~ Age + Size + C(Sex) + C(TimeofDay, Treatment(reference="lateday")) + C(WeekDay, Treatment(reference=6)) + C(Group, Treatment(reference="Toy")) + C(PureMixedHybrid,  Treatment(reference="Mixed")) + C(HasName) + C(IsIntact) + C(IsMixColor)', train_logit).fit()
# Out:
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/statsmodels/discrete/discrete_model.py:130: FutureWarning: icol(i) is deprecated. Please use .iloc[:,i]
#   endog_dummies = get_dummies(endog.icol(0))
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/statsmodels/discrete/discrete_model.py:580: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   start_params = np.zeros((self.K * (self.J-1)))
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/statsmodels/discrete/discrete_model.py:1840: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   params = params.reshape(self.K, -1, order='F')
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/statsmodels/discrete/discrete_model.py:1756: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   params = params.reshape(self.K, -1, order='F')
# Optimization terminated successfully.
#          Current function value: 0.938843
#          Iterations 8
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/statsmodels/discrete/discrete_model.py:1697: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   params = params.reshape(self.K, -1, order='F')
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/statsmodels/discrete/discrete_model.py:588: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   mnfit.params = mnfit.params.reshape(self.K, -1, order='F')

# %%
print(model.summary())
# Out:
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/statsmodels/discrete/discrete_model.py:1697: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   params = params.reshape(self.K, -1, order='F')
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/statsmodels/discrete/discrete_model.py:580: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   start_params = np.zeros((self.K * (self.J-1)))
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/statsmodels/discrete/discrete_model.py:1840: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   params = params.reshape(self.K, -1, order='F')
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/statsmodels/discrete/discrete_model.py:1756: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   params = params.reshape(self.K, -1, order='F')
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/statsmodels/discrete/discrete_model.py:588: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   mnfit.params = mnfit.params.reshape(self.K, -1, order='F')
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:            OutcomeType   No. Observations:                26372
# Model:                        MNLogit   Df Residuals:                    26294
# Method:                           MLE   Df Model:                           75
# Date:                Sun, 15 Jan 2017   Pseudo R-squ.:                  0.2068
# Time:                        22:06:28   Log-Likelihood:                -24759.
# converged:                       True   LL-Null:                       -31215.
#                                         LLR p-value:                     0.000
# ==============================================================================================================================
#                                              OutcomeType=1       coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                     -5.5644      0.181    -30.808      0.000        -5.918    -5.210
# C(Sex)[T.Male]                                                 0.4301      0.071      6.092      0.000         0.292     0.568
# C(TimeofDay, Treatment(reference="lateday"))[T.midday]         0.7530      0.077      9.753      0.000         0.602     0.904
# C(TimeofDay, Treatment(reference="lateday"))[T.morning]        1.6480      0.132     12.530      0.000         1.390     1.906
# C(TimeofDay, Treatment(reference="lateday"))[T.night]          0.3058      0.150      2.038      0.042         0.012     0.600
# C(WeekDay, Treatment(reference=6))[T.0]                        0.7676      0.138      5.543      0.000         0.496     1.039
# C(WeekDay, Treatment(reference=6))[T.1]                        0.9289      0.137      6.784      0.000         0.661     1.197
# C(WeekDay, Treatment(reference=6))[T.2]                        0.9570      0.139      6.899      0.000         0.685     1.229
# C(WeekDay, Treatment(reference=6))[T.3]                        1.1098      0.136      8.156      0.000         0.843     1.376
# C(WeekDay, Treatment(reference=6))[T.4]                        0.8508      0.138      6.154      0.000         0.580     1.122
# C(WeekDay, Treatment(reference=6))[T.5]                       -0.2195      0.151     -1.451      0.147        -0.516     0.077
# C(Group, Treatment(reference="Toy"))[T.Herding]                0.4901      0.183      2.682      0.007         0.132     0.848
# C(Group, Treatment(reference="Toy"))[T.Hound]                 -0.0362      0.194     -0.187      0.852        -0.416     0.343
# C(Group, Treatment(reference="Toy"))[T.NonSporting]            0.4572      0.183      2.502      0.012         0.099     0.815
# C(Group, Treatment(reference="Toy"))[T.PitBull]                1.8559      0.147     12.603      0.000         1.567     2.145
# C(Group, Treatment(reference="Toy"))[T.Sporting]               0.4634      0.164      2.818      0.005         0.141     0.786
# C(Group, Treatment(reference="Toy"))[T.Terrier]                0.1539      0.170      0.906      0.365        -0.179     0.487
# C(Group, Treatment(reference="Toy"))[T.Unknown]                0.5927      0.413      1.437      0.151        -0.216     1.401
# C(Group, Treatment(reference="Toy"))[T.Working]                0.8042      0.196      4.101      0.000         0.420     1.189
# C(PureMixedHybrid, Treatment(reference="Mixed"))[T.Hybrid]     0.0005      0.100      0.005      0.996        -0.196     0.197
# C(PureMixedHybrid, Treatment(reference="Mixed"))[T.Pure]       0.0048      0.143      0.034      0.973        -0.275     0.284
# C(HasName)[T.1]                                               -0.9655      0.092    -10.513      0.000        -1.145    -0.785
# C(IsIntact)[T.1.0]                                             3.8068      0.093     40.723      0.000         3.624     3.990
# C(IsMixColor)[T.1]                                            -0.0243      0.076     -0.322      0.748        -0.172     0.124
# Age                                                            1.6666      0.053     31.179      0.000         1.562     1.771
# Size                                                           0.0238      0.092      0.259      0.795        -0.156     0.203
# ------------------------------------------------------------------------------------------------------------------------------
#                                              OutcomeType=2       coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                     -4.0120      0.104    -38.559      0.000        -4.216    -3.808
# C(Sex)[T.Male]                                                 0.2751      0.033      8.427      0.000         0.211     0.339
# C(TimeofDay, Treatment(reference="lateday"))[T.midday]         0.2772      0.035      7.955      0.000         0.209     0.346
# C(TimeofDay, Treatment(reference="lateday"))[T.morning]       -1.2399      0.128     -9.704      0.000        -1.490    -0.989
# C(TimeofDay, Treatment(reference="lateday"))[T.night]         -0.0535      0.068     -0.792      0.429        -0.186     0.079
# C(WeekDay, Treatment(reference=6))[T.0]                        0.5444      0.058      9.350      0.000         0.430     0.659
# C(WeekDay, Treatment(reference=6))[T.1]                        0.6636      0.059     11.195      0.000         0.547     0.780
# C(WeekDay, Treatment(reference=6))[T.2]                        0.7067      0.061     11.630      0.000         0.588     0.826
# C(WeekDay, Treatment(reference=6))[T.3]                        0.6716      0.061     10.977      0.000         0.552     0.791
# C(WeekDay, Treatment(reference=6))[T.4]                        0.6098      0.060     10.148      0.000         0.492     0.728
# C(WeekDay, Treatment(reference=6))[T.5]                       -0.0780      0.058     -1.351      0.177        -0.191     0.035
# C(Group, Treatment(reference="Toy"))[T.Herding]                0.0143      0.077      0.186      0.852        -0.136     0.165
# C(Group, Treatment(reference="Toy"))[T.Hound]                  0.0316      0.073      0.434      0.664        -0.111     0.174
# C(Group, Treatment(reference="Toy"))[T.NonSporting]            0.2303      0.083      2.784      0.005         0.068     0.392
# C(Group, Treatment(reference="Toy"))[T.PitBull]                0.5700      0.068      8.344      0.000         0.436     0.704
# C(Group, Treatment(reference="Toy"))[T.Sporting]               0.1614      0.069      2.336      0.019         0.026     0.297
# C(Group, Treatment(reference="Toy"))[T.Terrier]                0.0813      0.068      1.186      0.236        -0.053     0.216
# C(Group, Treatment(reference="Toy"))[T.Unknown]               -0.3818      0.206     -1.852      0.064        -0.786     0.022
# C(Group, Treatment(reference="Toy"))[T.Working]                0.2317      0.086      2.699      0.007         0.063     0.400
# C(PureMixedHybrid, Treatment(reference="Mixed"))[T.Hybrid]    -0.1992      0.044     -4.525      0.000        -0.285    -0.113
# C(PureMixedHybrid, Treatment(reference="Mixed"))[T.Pure]       0.3802      0.065      5.888      0.000         0.254     0.507
# C(HasName)[T.1]                                                1.9843      0.086     23.155      0.000         1.816     2.152
# C(IsIntact)[T.1.0]                                             2.6788      0.071     37.918      0.000         2.540     2.817
# C(IsMixColor)[T.1]                                            -0.0219      0.035     -0.628      0.530        -0.090     0.046
# Age                                                            0.9987      0.025     39.318      0.000         0.949     1.048
# Size                                                           0.0584      0.039      1.504      0.133        -0.018     0.135
# ------------------------------------------------------------------------------------------------------------------------------
#                                              OutcomeType=3       coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                     -1.9939      0.083    -24.043      0.000        -2.156    -1.831
# C(Sex)[T.Male]                                                 0.1338      0.038      3.561      0.000         0.060     0.207
# C(TimeofDay, Treatment(reference="lateday"))[T.midday]         1.3616      0.042     32.710      0.000         1.280     1.443
# C(TimeofDay, Treatment(reference="lateday"))[T.morning]        0.1243      0.122      1.021      0.307        -0.114     0.363
# C(TimeofDay, Treatment(reference="lateday"))[T.night]          1.2615      0.069     18.260      0.000         1.126     1.397
# C(WeekDay, Treatment(reference=6))[T.0]                        0.6736      0.067     10.025      0.000         0.542     0.805
# C(WeekDay, Treatment(reference=6))[T.1]                        0.6238      0.070      8.967      0.000         0.487     0.760
# C(WeekDay, Treatment(reference=6))[T.2]                        0.6156      0.071      8.658      0.000         0.476     0.755
# C(WeekDay, Treatment(reference=6))[T.3]                        0.7093      0.071     10.056      0.000         0.571     0.848
# C(WeekDay, Treatment(reference=6))[T.4]                        0.6196      0.070      8.878      0.000         0.483     0.756
# C(WeekDay, Treatment(reference=6))[T.5]                       -0.1791      0.069     -2.589      0.010        -0.315    -0.044
# C(Group, Treatment(reference="Toy"))[T.Herding]               -0.3251      0.088     -3.701      0.000        -0.497    -0.153
# C(Group, Treatment(reference="Toy"))[T.Hound]                 -0.1102      0.080     -1.379      0.168        -0.267     0.046
# C(Group, Treatment(reference="Toy"))[T.NonSporting]           -0.0632      0.095     -0.667      0.504        -0.249     0.122
# C(Group, Treatment(reference="Toy"))[T.PitBull]                0.0062      0.080      0.077      0.938        -0.150     0.162
# C(Group, Treatment(reference="Toy"))[T.Sporting]              -0.1149      0.078     -1.473      0.141        -0.268     0.038
# C(Group, Treatment(reference="Toy"))[T.Terrier]               -0.1621      0.077     -2.113      0.035        -0.312    -0.012
# C(Group, Treatment(reference="Toy"))[T.Unknown]               -0.2588      0.217     -1.193      0.233        -0.684     0.166
# C(Group, Treatment(reference="Toy"))[T.Working]               -0.1703      0.100     -1.698      0.089        -0.367     0.026
# C(PureMixedHybrid, Treatment(reference="Mixed"))[T.Hybrid]    -0.0958      0.050     -1.917      0.055        -0.194     0.002
# C(PureMixedHybrid, Treatment(reference="Mixed"))[T.Pure]       0.3428      0.076      4.531      0.000         0.195     0.491
# C(HasName)[T.1]                                               -0.5907      0.052    -11.420      0.000        -0.692    -0.489
# C(IsIntact)[T.1.0]                                             3.2777      0.068     47.951      0.000         3.144     3.412
# C(IsMixColor)[T.1]                                            -0.0574      0.040     -1.443      0.149        -0.135     0.021
# Age                                                            0.3414      0.030     11.302      0.000         0.282     0.401
# Size                                                          -0.0139      0.045     -0.307      0.759        -0.103     0.075
# ==============================================================================================================================

# %%
aic(-25184, 26448, 11)
# Out:
# 50390.0

# %%
result = model.summary().as_csv()
print(result)
# Out:
#                   MNLogit Regression Results
# Dep. Variable:,OutcomeType     ,  No. Observations:  , 26372
# Model:        ,MNLogit         ,  Df Residuals:      , 26294
# Method:       ,MLE             ,  Df Model:          ,    75
# Date:         ,Sun, 15 Jan 2017,  Pseudo R-squ.:     ,0.2068
# Time:         ,22:06:28        ,  Log-Likelihood:    , -24759.
# converged:    ,True            ,  LL-Null:           , -31215.
#               ,                ,  LLR p-value:       , 0.000
#                       OutcomeType=1                       ,   coef   , std err ,    z    ,P>|z| , [95.0% Conf. Int.]
# Intercept                                                 ,   -5.5644,    0.181,  -30.808, 0.000,   -5.918    -5.210
# C(Sex)[T.Male]                                            ,    0.4301,    0.071,    6.092, 0.000,    0.292     0.568
# C(TimeofDay, Treatment(reference="lateday"))[T.midday]    ,    0.7530,    0.077,    9.753, 0.000,    0.602     0.904
# C(TimeofDay, Treatment(reference="lateday"))[T.morning]   ,    1.6480,    0.132,   12.530, 0.000,    1.390     1.906
# C(TimeofDay, Treatment(reference="lateday"))[T.night]     ,    0.3058,    0.150,    2.038, 0.042,    0.012     0.600
# C(WeekDay, Treatment(reference=6))[T.0]                   ,    0.7676,    0.138,    5.543, 0.000,    0.496     1.039
# C(WeekDay, Treatment(reference=6))[T.1]                   ,    0.9289,    0.137,    6.784, 0.000,    0.661     1.197
# C(WeekDay, Treatment(reference=6))[T.2]                   ,    0.9570,    0.139,    6.899, 0.000,    0.685     1.229
# C(WeekDay, Treatment(reference=6))[T.3]                   ,    1.1098,    0.136,    8.156, 0.000,    0.843     1.376
# C(WeekDay, Treatment(reference=6))[T.4]                   ,    0.8508,    0.138,    6.154, 0.000,    0.580     1.122
# C(WeekDay, Treatment(reference=6))[T.5]                   ,   -0.2195,    0.151,   -1.451, 0.147,   -0.516     0.077
# C(Group, Treatment(reference="Toy"))[T.Herding]           ,    0.4901,    0.183,    2.682, 0.007,    0.132     0.848
# C(Group, Treatment(reference="Toy"))[T.Hound]             ,   -0.0362,    0.194,   -0.187, 0.852,   -0.416     0.343
# C(Group, Treatment(reference="Toy"))[T.NonSporting]       ,    0.4572,    0.183,    2.502, 0.012,    0.099     0.815
# C(Group, Treatment(reference="Toy"))[T.PitBull]           ,    1.8559,    0.147,   12.603, 0.000,    1.567     2.145
# C(Group, Treatment(reference="Toy"))[T.Sporting]          ,    0.4634,    0.164,    2.818, 0.005,    0.141     0.786
# C(Group, Treatment(reference="Toy"))[T.Terrier]           ,    0.1539,    0.170,    0.906, 0.365,   -0.179     0.487
# C(Group, Treatment(reference="Toy"))[T.Unknown]           ,    0.5927,    0.413,    1.437, 0.151,   -0.216     1.401
# C(Group, Treatment(reference="Toy"))[T.Working]           ,    0.8042,    0.196,    4.101, 0.000,    0.420     1.189
# C(PureMixedHybrid, Treatment(reference="Mixed"))[T.Hybrid],    0.0005,    0.100,    0.005, 0.996,   -0.196     0.197
# C(PureMixedHybrid, Treatment(reference="Mixed"))[T.Pure]  ,    0.0048,    0.143,    0.034, 0.973,   -0.275     0.284
# C(HasName)[T.1]                                           ,   -0.9655,    0.092,  -10.513, 0.000,   -1.145    -0.785
# C(IsIntact)[T.1.0]                                        ,    3.8068,    0.093,   40.723, 0.000,    3.624     3.990
# C(IsMixColor)[T.1]                                        ,   -0.0243,    0.076,   -0.322, 0.748,   -0.172     0.124
# Age                                                       ,    1.6666,    0.053,   31.179, 0.000,    1.562     1.771
# Size                                                      ,    0.0238,    0.092,    0.259, 0.795,   -0.156     0.203
# --------------------------------------------------------------------------------------------------------------------
#                       OutcomeType=2                       ,   coef   , std err ,    z    ,P>|z| , [95.0% Conf. Int.]
# Intercept                                                 ,   -4.0120,    0.104,  -38.559, 0.000,   -4.216    -3.808
# C(Sex)[T.Male]                                            ,    0.2751,    0.033,    8.427, 0.000,    0.211     0.339
# C(TimeofDay, Treatment(reference="lateday"))[T.midday]    ,    0.2772,    0.035,    7.955, 0.000,    0.209     0.346
# C(TimeofDay, Treatment(reference="lateday"))[T.morning]   ,   -1.2399,    0.128,   -9.704, 0.000,   -1.490    -0.989
# C(TimeofDay, Treatment(reference="lateday"))[T.night]     ,   -0.0535,    0.068,   -0.792, 0.429,   -0.186     0.079
# C(WeekDay, Treatment(reference=6))[T.0]                   ,    0.5444,    0.058,    9.350, 0.000,    0.430     0.659
# C(WeekDay, Treatment(reference=6))[T.1]                   ,    0.6636,    0.059,   11.195, 0.000,    0.547     0.780
# C(WeekDay, Treatment(reference=6))[T.2]                   ,    0.7067,    0.061,   11.630, 0.000,    0.588     0.826
# C(WeekDay, Treatment(reference=6))[T.3]                   ,    0.6716,    0.061,   10.977, 0.000,    0.552     0.791
# C(WeekDay, Treatment(reference=6))[T.4]                   ,    0.6098,    0.060,   10.148, 0.000,    0.492     0.728
# C(WeekDay, Treatment(reference=6))[T.5]                   ,   -0.0780,    0.058,   -1.351, 0.177,   -0.191     0.035
# C(Group, Treatment(reference="Toy"))[T.Herding]           ,    0.0143,    0.077,    0.186, 0.852,   -0.136     0.165
# C(Group, Treatment(reference="Toy"))[T.Hound]             ,    0.0316,    0.073,    0.434, 0.664,   -0.111     0.174
# C(Group, Treatment(reference="Toy"))[T.NonSporting]       ,    0.2303,    0.083,    2.784, 0.005,    0.068     0.392
# C(Group, Treatment(reference="Toy"))[T.PitBull]           ,    0.5700,    0.068,    8.344, 0.000,    0.436     0.704
# C(Group, Treatment(reference="Toy"))[T.Sporting]          ,    0.1614,    0.069,    2.336, 0.019,    0.026     0.297
# C(Group, Treatment(reference="Toy"))[T.Terrier]           ,    0.0813,    0.068,    1.186, 0.236,   -0.053     0.216
# C(Group, Treatment(reference="Toy"))[T.Unknown]           ,   -0.3818,    0.206,   -1.852, 0.064,   -0.786     0.022
# C(Group, Treatment(reference="Toy"))[T.Working]           ,    0.2317,    0.086,    2.699, 0.007,    0.063     0.400
# C(PureMixedHybrid, Treatment(reference="Mixed"))[T.Hybrid],   -0.1992,    0.044,   -4.525, 0.000,   -0.285    -0.113
# C(PureMixedHybrid, Treatment(reference="Mixed"))[T.Pure]  ,    0.3802,    0.065,    5.888, 0.000,    0.254     0.507
# C(HasName)[T.1]                                           ,    1.9843,    0.086,   23.155, 0.000,    1.816     2.152
# C(IsIntact)[T.1.0]                                        ,    2.6788,    0.071,   37.918, 0.000,    2.540     2.817
# C(IsMixColor)[T.1]                                        ,   -0.0219,    0.035,   -0.628, 0.530,   -0.090     0.046
# Age                                                       ,    0.9987,    0.025,   39.318, 0.000,    0.949     1.048
# Size                                                      ,    0.0584,    0.039,    1.504, 0.133,   -0.018     0.135
# --------------------------------------------------------------------------------------------------------------------
#                       OutcomeType=3                       ,   coef   , std err ,    z    ,P>|z| , [95.0% Conf. Int.]
# Intercept                                                 ,   -1.9939,    0.083,  -24.043, 0.000,   -2.156    -1.831
# C(Sex)[T.Male]                                            ,    0.1338,    0.038,    3.561, 0.000,    0.060     0.207
# C(TimeofDay, Treatment(reference="lateday"))[T.midday]    ,    1.3616,    0.042,   32.710, 0.000,    1.280     1.443
# C(TimeofDay, Treatment(reference="lateday"))[T.morning]   ,    0.1243,    0.122,    1.021, 0.307,   -0.114     0.363
# C(TimeofDay, Treatment(reference="lateday"))[T.night]     ,    1.2615,    0.069,   18.260, 0.000,    1.126     1.397
# C(WeekDay, Treatment(reference=6))[T.0]                   ,    0.6736,    0.067,   10.025, 0.000,    0.542     0.805
# C(WeekDay, Treatment(reference=6))[T.1]                   ,    0.6238,    0.070,    8.967, 0.000,    0.487     0.760
# C(WeekDay, Treatment(reference=6))[T.2]                   ,    0.6156,    0.071,    8.658, 0.000,    0.476     0.755
# C(WeekDay, Treatment(reference=6))[T.3]                   ,    0.7093,    0.071,   10.056, 0.000,    0.571     0.848
# C(WeekDay, Treatment(reference=6))[T.4]                   ,    0.6196,    0.070,    8.878, 0.000,    0.483     0.756
# C(WeekDay, Treatment(reference=6))[T.5]                   ,   -0.1791,    0.069,   -2.589, 0.010,   -0.315    -0.044
# C(Group, Treatment(reference="Toy"))[T.Herding]           ,   -0.3251,    0.088,   -3.701, 0.000,   -0.497    -0.153
# C(Group, Treatment(reference="Toy"))[T.Hound]             ,   -0.1102,    0.080,   -1.379, 0.168,   -0.267     0.046
# C(Group, Treatment(reference="Toy"))[T.NonSporting]       ,   -0.0632,    0.095,   -0.667, 0.504,   -0.249     0.122
# C(Group, Treatment(reference="Toy"))[T.PitBull]           ,    0.0062,    0.080,    0.077, 0.938,   -0.150     0.162
# C(Group, Treatment(reference="Toy"))[T.Sporting]          ,   -0.1149,    0.078,   -1.473, 0.141,   -0.268     0.038
# C(Group, Treatment(reference="Toy"))[T.Terrier]           ,   -0.1621,    0.077,   -2.113, 0.035,   -0.312    -0.012
# C(Group, Treatment(reference="Toy"))[T.Unknown]           ,   -0.2588,    0.217,   -1.193, 0.233,   -0.684     0.166
# C(Group, Treatment(reference="Toy"))[T.Working]           ,   -0.1703,    0.100,   -1.698, 0.089,   -0.367     0.026
# C(PureMixedHybrid, Treatment(reference="Mixed"))[T.Hybrid],   -0.0958,    0.050,   -1.917, 0.055,   -0.194     0.002
# C(PureMixedHybrid, Treatment(reference="Mixed"))[T.Pure]  ,    0.3428,    0.076,    4.531, 0.000,    0.195     0.491
# C(HasName)[T.1]                                           ,   -0.5907,    0.052,  -11.420, 0.000,   -0.692    -0.489
# C(IsIntact)[T.1.0]                                        ,    3.2777,    0.068,   47.951, 0.000,    3.144     3.412
# C(IsMixColor)[T.1]                                        ,   -0.0574,    0.040,   -1.443, 0.149,   -0.135     0.021
# Age                                                       ,    0.3414,    0.030,   11.302, 0.000,    0.282     0.401
# Size                                                      ,   -0.0139,    0.045,   -0.307, 0.759,   -0.103     0.075

# %% [markdown]
# # Make prediction

# %%
predict_label = model.predict(test_data_logit)

# %%
predict_label
# Out:
# array([[ 0.58578906,  0.10704647,  0.15273032,  0.15443414],
#        [ 0.00953281,  0.20267162,  0.49682079,  0.29097478],
#        [ 0.57364595,  0.00661403,  0.18308032,  0.23665969],
#        ...,
#        [ 0.5474361 ,  0.00413927,  0.19763   ,  0.25079463],
#        [ 0.47442052,  0.01553275,  0.42813444,  0.08191228],
#        [ 0.06834278,  0.02247717,  0.24410706,  0.66507298]])

# %%
predict = np.argmax(predict_label, axis=1)

# %%
predict
# Out:
# array([0, 2, 0, ..., 0, 0, 3])

# %% [markdown]
# # Accuracy and score

# %%
# Accuracy
# model.score(test_data, test_label)

# %%
accuracy_score(test_label_logit, predict)
# Out:
# 0.60488396784468379

# %%
# Log loss
log_loss(test_label, predict_label, eps=1e-15, normalize=True)
# Out:
# 0.93372290962488746

# %%
precision_recall_fscore_support(test_label_logit, predict, beta=0.5, average=None)
# Out:
# (array([ 0.64005102,  0.44444444,  0.52066116,  0.63222632]),
#  array([ 0.83466401,  0.07575758,  0.49321503,  0.36531628]),
#  array([ 0.67135824,  0.22522523,  0.51493025,  0.55162052]),
#  array([3006,  264, 1916, 1407]))

# %% [markdown]
# # Plot confusion matrix

# %%
def plot_confusion_matrix(cm, classes, normalize=False,
                          title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    
    plt.title(title)
   
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    
    #plt.yticks(tick_marks, classes, rotation=45)
    #plt.xticks(tick_marks, classes)
    
    if normalize:
        cm = np.round(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)
        plt.imshow(cm, interpolation='nearest', cmap=cmap)
        plt.colorbar()
        print("Normalized confusion matrix")
    else:
        plt.imshow(cm, interpolation='nearest', cmap=cmap)
        plt.colorbar()
        print('Confusion matrix, without normalization')

    print(cm)
    
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# Compute confusion matrix
cnf_matrix = confusion_matrix(test_label_logit, predict)
np.set_printoptions(precision=2)
class_names = label_list
# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
plt.savefig('fg/confusion_matrix_wo_normalize.png')
# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')
plt.savefig('fg/confusion_matrix_w_normalize.png')
plt.show()
plt.close()
# Out:
# Confusion matrix, without normalization
# [[2509    3  433   61]
#  [  52   20  100   92]
#  [ 821    4  945  146]
#  [ 538   18  337  514]]
# Normalized confusion matrix
# [[ 0.83  0.    0.14  0.02]
#  [ 0.2   0.08  0.38  0.35]
#  [ 0.43  0.    0.49  0.08]
#  [ 0.38  0.01  0.24  0.37]]

# %%
def confusion_probs(predictions, labels, ax = None, vmargin = 0.1, equalize = False, cmap = cm.jet, colors = [],ticklabels=[]):
    """
        Make a confusion-matrix-like scatter plot
    """
    N, D = predictions.shape
    bins = bincount(labels)
    assert labels.min() >= 0 and labels.max() < D, 'labels should be between 0 and {0:d}'.format(D - 1)
    assert predictions.min() >= 0 and predictions.max() <= 1, 'predictions should be normalized (to [0, 1])'
    """ Set up graphical stuff. """
    fig = None
    if ax is None:
        fig, ax = subplots(figsize = (7, 7))
        fig.tight_layout()
    if equalize:
        xticks = [x + .5 for x in range(D)]
        bin_left = range(D)
        bin_right = range(1,D+1)
    else:
        xticks = (float(D) / N) * (cumsum(bins) - bins / 2)
        bin_left = (float(D) / N) * (cumsum(bins) - bins)
        bin_right = (float(D) / N) * (cumsum(bins))
        
    ax.set_xticks(xticks)
    if len(ticklabels) == 0:
        ax.set_xticklabels(range(D))
    else:
        ax.set_xticklabels(ticklabels,rotation=90)
        
    ax.set_xlim([0, D])
    ax.set_yticks([(x + .5) * (1 + vmargin) for x in range(D)])
    if len(ticklabels) == 0:
        ax.set_yticklabels(range(D))
    else:
        ax.set_yticklabels(ticklabels)
    
    
    ax.set_ylim([0, D * (1 + vmargin) - vmargin])
    ax.set_xlabel('True classes')
    ax.set_ylabel('Prediction probabilities')
    """ Sort predictions by label. """
    indices = labels.argsort()
    X = predictions[indices, :]
    y = labels[indices]
    """ Add more vertical offset to higher labels. """
    X += linspace(0, D - 1, D) * (1 + vmargin)
    """ Make a new horizontal axis to give all samples equal width. """
    if equalize:
        z = hstack([k + linspace(0, 1, t) for k, t in enumerate(bins)])
    else:
        z = linspace(0, D, N)
    """ Plot the results with class-coding. """
    if len(colors) == 0:
        colors = []
        for q in range(D):
            colors.append(cmap(y / float(D)))
    for q in range(D):
        row = X[:, q]
        for qq in range(D):
            if qq == 3:
                ax.scatter(z[(z > bin_left[qq])&(z<bin_right[qq])], row[(z > bin_left[qq])&(z<bin_right[qq])], c = colors[qq], edgecolors = 'k',linewidth=0.1,s=5)
            else:
                ax.scatter(z[(z > bin_left[qq])&(z<bin_right[qq])], row[(z > bin_left[qq])&(z<bin_right[qq])], c = colors[qq],edgecolor='None',s=5)
    plt.tight_layout()
    return (fig, ax) if fig else ax

colors = ['#ffcee5','#3C7DC4','#f9fc37','#FFF5EE']
ticklabels = label_list
fig, ax = confusion_probs(predict_label, test_label_logit, equalize = True,colors = colors,ticklabels = ticklabels)
fig.savefig('fg/conf_mat_probs_equalized.png')
plt.show()
plt.close()
