# %%
import pandas as pd
import datetime as dt
from dateutil.parser import parse
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pickle
from sklearn.preprocessing import (Imputer, LabelEncoder, OneHotEncoder, StandardScaler)
# %matplotlib inline
pd.options.mode.chained_assignment = None

# %%
# Read data
train = pd.read_csv("train.csv", header=0)
dog_breeds = pd.read_csv("dog_breeds.csv", header = 0)

# %%
#train

# %% [markdown]
# # Data preprocessing

# %%
"""
Data of dogs: Subset data of dogs
"""
sns.countplot(train.AnimalType, palette='Set3')

# %%
#train.query("AnimalType == 'Dog'")
train = train[train['AnimalType'] == 'Dog']

# %% [markdown]
# # ----------------------Name----------------------
# Objective: Non-metric variable: HasName (0: has name, 1: no name)

# %%
# Replace blank names with "Nameless"
train['Name'].fillna("Nameless", inplace = True)

# %%
# Define function
def hasName(name):
    if name == "Nameless":
        return 0
    else:
        return 1

# %%
# Apply function
train['HasName'] = train['Name'].apply(hasName)

# %%
sns.countplot(train.HasName, palette='Set3')

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 4))
sns.countplot(data=train, x='OutcomeType',hue='HasName', palette='Set2', ax=ax1)
sns.countplot(data=train, x='HasName',hue='OutcomeType', palette='Set3', ax=ax2)

# %% [markdown]
# # ----------------------DateTime----------------------
# Objective:  Non metric variable: TimeofDay (morning, midday, lateday and night)
#            Non metric variable: WeekDay (0, 1, 2, 3, 4, 5, 6)

# %%
# Define function
def time_of_day(x):
    x = str(x)
    time = x.split()[1]
    hour = int(time.split(":")[0])
    if hour >= 5 and hour < 11: return "morning"
    if hour >= 11 and hour < 16: return "midday"
    if hour >= 15 and hour < 20: return "lateday"
    else: return "night"

# %%
# Apply function
train['TimeofDay'] = train['DateTime'].apply(time_of_day)

# %%
sns.countplot(train.TimeofDay, palette='Set3')

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 4))
sns.countplot(data=train, x='OutcomeType',hue='TimeofDay', palette='Set2', ax=ax1)
sns.countplot(data=train, x='TimeofDay',hue='OutcomeType', palette='Set3', ax=ax2)

# %%
train['DateTime'] = pd.to_datetime(train['DateTime'], errors='coerce')

# %%
train['WeekDay'] = train['DateTime'].dt.dayofweek

# %%
sns.countplot(train.WeekDay, palette='Set3')

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 4))
sns.countplot(data=train, x='OutcomeType',hue='WeekDay', palette='Set2', ax=ax1)
sns.countplot(data=train, x='WeekDay',hue='OutcomeType', palette='Set3', ax=ax2)

# %% [markdown]
# # ----------------------OutcomeType----------------------
# Objective: Non metric dependent variable Outcome (Return_to_owner, Adoption, Transfer, Euthanasia, Died)

# %%
sns.countplot(train.OutcomeType, palette='Set3')

# %%
"""
# TODO: mapping
class_mapping = {label: idx for idx, label in enumerate(np.unique(train['OutcomeType']))}
class_mapping
train['OutcomeType'] = train['OutcomeType'].map(class_mapping)
"""
# Out:
# "\n# TODO: mapping\nclass_mapping = {label: idx for idx, label in enumerate(np.unique(train['OutcomeType']))}\nclass_mapping\ntrain['OutcomeType'] = train['OutcomeType'].map(class_mapping)\n"

# %% [markdown]
# # ----------------------OutcomeSubtype----------------------
# Objective: Delete this unused variable

# %%
train.drop("OutcomeSubtype", axis=1, inplace=True)

# %% [markdown]
# # ----------------------SexuponOutcome----------------------
# Objective:  Non metric variable: IsIntact (0: no, 1: yes)
#             Non metric variable: Sex (Male, Female)

# %%
sns.countplot(train.SexuponOutcome, palette='Set3')

# %%
def getSex(x):
    x = str(x)
    if x.find('Male') >= 0: return "Male"
    if x.find('Female') >= 0: return "Female"
    #return "Unknown"
def getIntactness(x):
    x = str(x)
    if x.find('Neutered') >= 0: return 0
    if x.find('Spayed') >= 0: return 0
    if x.find('Intact') >= 0: return 1
    #return "Unknown"

# %%
train['SexuponOutcome'].unique()
# Out:
# array(['Neutered Male', 'Intact Female', 'Spayed Female', 'Intact Male',
#        'Unknown', nan], dtype=object)

# %%
train['Sex'] = train['SexuponOutcome'].apply(getSex)
train['IsIntact'] = train['SexuponOutcome'].apply(getIntactness)

# %%
#train["Sex"].value_counts()
#train["IsIntact"].value_counts()

# %%
#train

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 4))
sns.countplot(train.Sex, palette='Set2', ax=ax1)
sns.countplot(train.IsIntact, palette='Set3', ax=ax2)

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 4))
sns.countplot(data=train, x='OutcomeType',hue='Sex', palette='Set2', ax=ax1)
sns.countplot(data=train, x='Sex',hue='OutcomeType', palette='Set3', ax=ax2)

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 4))
sns.countplot(data=train, x='OutcomeType',hue='IsIntact', palette='Set2', ax=ax1)
sns.countplot(data=train, x='IsIntact',hue='OutcomeType', palette='Set2', ax=ax2)

# %% [markdown]
# # ----------------------AgeuponOutcome----------------------
# Objective:  Metric variable: AgeinYears (age of animal)
#             Non metric variable: Age (Juvenile, Adult, Old)

# %%
def calcAgeInYears(x):
    x = str(x)
    if x == 'nan': return 0
    age = int(x.split()[0])
    if x.find('year') > -1: return age 
    if x.find('month')> -1: return age / 12.
    if x.find('week')> -1: return age / 52.
    if x.find('day')> -1: return age / 365.
    else: return 0

# %%
train['AgeInYears'] = train['AgeuponOutcome'].apply(calcAgeInYears)
sns.distplot(train.AgeInYears, bins = 20, kde=False)

# %%
def Age(x):
    if x <2: return "Juvenile"
    if x >= 2 and x <= 6: return "Adult"
    else: return "Old"

# %%
train["Age"] = train["AgeInYears"].apply(Age)

# %%
sns.countplot(train.Age, palette='Set2')

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 4))
sns.countplot(data=train, x='OutcomeType',hue='Age', palette='Set2', ax=ax1)
sns.countplot(data=train, x='Age',hue='OutcomeType', palette='Set3', ax=ax2)

# %% [markdown]
# # ----------------------Breed----------------------
# Objective:  Non metric variable: IsMixBreed (0: no, 1: yes)
#             Non metric variable: MixorMultipleorSimple (Mix, Multiple, Simple)
#             Non metric variable: Group (Sporting, NonSporting, Hound, Working, Terrier, Toy, Herding, Pitbull)
#             Non metric variable: Size (S, M, L and G)
# Temperament Non metric variable: IsIntelligent (0: no, 1: yes)
#             Non metric variable: IsAggressive (0: no, 1: yes)

# %%
def mixBreed(x):
    if x.find("Mix") >= 0: return 1
    else: return 0

# %%
train["IsMixBreed"] = train["Breed"].apply(mixBreed)

# %%
#train["IsMixBreed"].head

# %%
sns.countplot(train.IsMixBreed, palette='Set2')

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 4))
sns.countplot(data=train, x='OutcomeType',hue='IsMixBreed', palette='Set2', ax=ax1)
sns.countplot(data=train, x='IsMixBreed',hue='OutcomeType', palette='Set3', ax=ax2)

# %%
def mix_multiple_simple(x):
    if x.find("Mix") >= 0:
        return "Mix"
    elif x.find("/") >= 0:
        return "Multiple"
    else:
        return "Simple"

# %%
train["MixorMultipleorSimple"] = train["Breed"].apply(mix_multiple_simple)

# %%
sns.countplot(train.MixorMultipleorSimple, palette='Set2')

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 4))
sns.countplot(data=train, x='OutcomeType',hue='MixorMultipleorSimple', palette='Set2', ax=ax1)
sns.countplot(data=train, x='MixorMultipleorSimple',hue='OutcomeType', palette='Set3', ax=ax2)

# %%
# Keep simple and dominant breed
def keepSimpleBreed(x):
    if x.find("/") >= 0:
        x.split("/")
        x = x.split("/")[0]
    if x.find("Mix") >= 0:
        x = x[:-4]
    return x

# %%
train["SimpleBreed"] = train["Breed"].apply(keepSimpleBreed)

# %%
#train["SimpleBreed"]

# %%
# Merge dataframe
Animals = pd.merge(train, dog_breeds, on='SimpleBreed', how = "left")

# %%
sns.countplot(Animals.Size, palette='Set2')

# %%
sns.countplot(Animals.Group, palette='Set2')

# %%
#Animals

# %%
#f, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 4))
f, (ax1) = plt.subplots(1, 1, figsize=(16, 4))
sns.countplot(data=Animals, x='OutcomeType',hue='Group', palette='Set3', ax=ax1)
f, (ax2) = plt.subplots(1, 1, figsize=(16, 4))
sns.countplot(data=Animals, x='Group',hue='OutcomeType', palette='Set3', ax=ax2)

# %%
sns.countplot(Animals.Size, palette='Set2')

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 4))
sns.countplot(data=Animals, x='OutcomeType',hue='Size', palette='Set2', ax=ax1)
sns.countplot(data=Animals, x='Size',hue='OutcomeType', palette='Set3', ax=ax2)

# %% [markdown]
# # ----------------------Color----------------------
# Objective: Non metric variable: IsMixColor (0: no, 1: yes)

# %%
def mixColor(x):
    x = str(x)
    if x.find("/") >= 0: return 1
    else: return 0

# %%
Animals["IsMixColor"] = Animals["Color"].apply(mixColor)

# %%
sns.countplot(Animals.IsMixColor, palette='Set2')

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 4))
sns.countplot(data=Animals, x='OutcomeType',hue='IsMixColor', palette='Set2', ax=ax1)
sns.countplot(data=Animals, x='IsMixColor',hue='OutcomeType', palette='Set3', ax=ax2)

# %%
def simpleColor(x):
    if x.find("/") >=0:
        return x.split("/")[0]
    else: return x

# %%
Animals["SimpleColor"] = Animals["Color"].apply(simpleColor)

# %%
#Animals["SimpleColor"].value_counts()

# %% [markdown]
# # ----------------------Check variables----------------------

# %%
#Animals["HasName"].unique()

# %%
#Animals["TimeofDay"].unique()

# %%
#Animals["WeekDay"].unique()

# %%
#Animals["OutcomeType"].unique()

# %%
#Animals["IsIntact"].unique()

# %%
#Animals["Sex"].unique()

# %%
#Animals["Age"].unique()

# %%
#Animals["IsMixBreed"].unique()

# %%
#Animals["MixorMultipleorSimple"].unique()

# %%
#Animals["Group"].unique()

# %%
#Animals["Size"].unique()

# %%
#Animals["IsIntelligent"].unique()

# %%
#Animals["IsAggressive"].unique()

# %%
#Animals["IsMixColor"].unique()

# %% [markdown]
# # ----------------------Delete missing values----------------------
# Objectives: Delete categorical variable: SexuponOutcome --> IsIntact
#             Delete categorical variable: Size

# %%
Animals.isnull().sum()
# Out:
# AnimalID                  0
# Name                      0
# DateTime                  0
# OutcomeType               0
# AnimalType                0
# SexuponOutcome            1
# AgeuponOutcome            1
# Breed                     0
# Color                     0
# HasName                   0
# TimeofDay                 0
# WeekDay                   0
# Sex                      78
# IsIntact                 78
# AgeInYears                0
# Age                       0
# IsMixBreed                0
# MixorMultipleorSimple     0
# SimpleBreed               0
# Group                    17
# Size                     17
# IsMixColor                0
# SimpleColor               0
# dtype: int64

# %%
Animals = Animals.dropna()

# %%
#Animals.isnull().sum()

# %%
#Animals

# %%
# Map ordinal independence variable
age_mapping = {"Juvenile": 0, "Adult": 1, "Old": 2}
Animals["Age"] = Animals["Age"].map(age_mapping)

size_mapping = {'S': 0, 'M': 1, 'L': 2, 'G':3}
Animals['Size'] = Animals['Size'].map(size_mapping)

# %%
#Animals.to_csv("animal_shelter.csv", sep='\t', encoding='utf-8')

# %%
OutcomeType = Animals['OutcomeType']

HasName = Animals['HasName']
TimeofDay = Animals["TimeofDay"]
WeekDay = Animals["WeekDay"]
IsIntact = Animals["IsIntact"]
Sex = Animals["Sex"]
Age = Animals["Age"]
MixorMultipleorSimple = Animals["MixorMultipleorSimple"]
Group = Animals["Group"]
Size = Animals["Size"]
IsMixColor = Animals["IsMixColor"]

# %%
f = 'OutcomeType ~ C(HasName) + C(TimeofDay) + C(WeekDay) + C(IsIntact) + C(Sex) + Age + C(MixorMultipleorSimple) + \
            C(Group) + Size + C(IsMixColor)'

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
logit_model = smf.logit(formula = str(f), data = Animals).fit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-7df9fea3778c> in <module>()
# ----> 1 logit_model = smf.logit(formula = str(f), data = Animals).fit()
#
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/statsmodels/discrete/discrete_model.py in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#    1374         bnryfit = super(Logit, self).fit(start_params=start_params,
#    1375                 method=method, maxiter=maxiter, full_output=full_output,
# -> 1376                 disp=disp, callback=callback, **kwargs)
#    1377
#    1378         discretefit = LogitResults(self, bnryfit)
#
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/statsmodels/discrete/discrete_model.py in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#     201         mlefit = super(DiscreteModel, self).fit(start_params=start_params,
#     202                 method=method, maxiter=maxiter, full_output=full_output,
# --> 203                 disp=disp, callback=callback, **kwargs)
#     204
#     205         return mlefit # up to subclasses to wrap results
#
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     423                                                        callback=callback,
#     424                                                        retall=retall,
# --> 425                                                        full_output=full_output)
#     426
#     427         #NOTE: this is for fit_regularized and should be generalized
#
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/statsmodels/base/optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     182                             disp=disp, maxiter=maxiter, callback=callback,
#     183                             retall=retall, full_output=full_output,
# --> 184                             hess=hessian)
#     185
#     186         # this is stupid TODO: just change this to something sane
#
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/statsmodels/base/optimizer.py in _fit_newton(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess, ridge_factor)
#     242         oldparams = newparams
#     243         newparams = oldparams - np.dot(np.linalg.inv(H),
# --> 244                 score(oldparams))
#     245         if retall:
#     246             history.append(newparams)
#
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/statsmodels/base/model.py in <lambda>(params)
#     409
#     410         if method == 'newton':
# --> 411             score = lambda params: self.score(params) / nobs
#     412             hess = lambda params: self.hessian(params) / nobs
#     413             #TODO: why are score and hess positive?
#
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/statsmodels/discrete/discrete_model.py in score(self, params)
#    1314         X = self.exog
#    1315         L = self.cdf(np.dot(X,params))
# -> 1316         return np.dot(y - L,X)
#    1317
#    1318     def score_obs(self, params):
#
# ValueError: operands could not be broadcast together with shapes (15499,5) (15499,)

# %%
logit_model.fit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-5279284cb04b> in <module>()
# ----> 1 logit_model.fit()
#
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/statsmodels/discrete/discrete_model.py in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#    1374         bnryfit = super(Logit, self).fit(start_params=start_params,
#    1375                 method=method, maxiter=maxiter, full_output=full_output,
# -> 1376                 disp=disp, callback=callback, **kwargs)
#    1377
#    1378         discretefit = LogitResults(self, bnryfit)
#
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/statsmodels/discrete/discrete_model.py in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#     201         mlefit = super(DiscreteModel, self).fit(start_params=start_params,
#     202                 method=method, maxiter=maxiter, full_output=full_output,
# --> 203                 disp=disp, callback=callback, **kwargs)
#     204
#     205         return mlefit # up to subclasses to wrap results
#
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     423                                                        callback=callback,
#     424                                                        retall=retall,
# --> 425                                                        full_output=full_output)
#     426
#     427         #NOTE: this is for fit_regularized and should be generalized
#
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/statsmodels/base/optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     182                             disp=disp, maxiter=maxiter, callback=callback,
#     183                             retall=retall, full_output=full_output,
# --> 184                             hess=hessian)
#     185
#     186         # this is stupid TODO: just change this to something sane
#
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/statsmodels/base/optimizer.py in _fit_newton(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess, ridge_factor)
#     242         oldparams = newparams
#     243         newparams = oldparams - np.dot(np.linalg.inv(H),
# --> 244                 score(oldparams))
#     245         if retall:
#     246             history.append(newparams)
#
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/statsmodels/base/model.py in <lambda>(params)
#     409
#     410         if method == 'newton':
# --> 411             score = lambda params: self.score(params) / nobs
#     412             hess = lambda params: self.hessian(params) / nobs
#     413             #TODO: why are score and hess positive?
#
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/statsmodels/discrete/discrete_model.py in score(self, params)
#    1314         X = self.exog
#    1315         L = self.cdf(np.dot(X,params))
# -> 1316         return np.dot(y - L,X)
#    1317
#    1318     def score_obs(self, params):
#
# ValueError: operands could not be broadcast together with shapes (15499,5) (15499,)

# %%
OutcomeType
#HasName
# Out:
# 0        Return_to_owner
# 1               Adoption
# 2               Transfer
# 3               Transfer
# 4               Adoption
# 5               Adoption
# 6               Adoption
# 7               Adoption
# 8        Return_to_owner
# 9        Return_to_owner
# 10              Transfer
# 11       Return_to_owner
# 12              Transfer
# 13              Adoption
# 14              Adoption
# 15       Return_to_owner
# 16              Adoption
# 17              Adoption
# 18              Transfer
# 19       Return_to_owner
# 20              Transfer
# 21            Euthanasia
# 22       Return_to_owner
# 23       Return_to_owner
# 24              Adoption
# 25            Euthanasia
# 26              Adoption
# 27              Transfer
# 28       Return_to_owner
# 29              Adoption
#               ...
# 15565    Return_to_owner
# 15566    Return_to_owner
# 15567         Euthanasia
# 15568    Return_to_owner
# 15569           Transfer
# 15570    Return_to_owner
# 15571    Return_to_owner
# 15572    Return_to_owner
# 15573           Adoption
# 15574           Transfer
# 15575    Return_to_owner
# 15576           Transfer
# 15577         Euthanasia
# 15578    Return_to_owner
# 15579           Adoption
# 15580    Return_to_owner
# 15581         Euthanasia
# 15582    Return_to_owner
# 15583           Transfer
# 15584           Transfer
# 15585           Adoption
# 15586           Transfer
# 15587           Transfer
# 15588    Return_to_owner
# 15589           Adoption
# 15590           Adoption
# 15591    Return_to_owner
# 15592           Adoption
# 15593           Adoption
# 15594           Adoption
# Name: OutcomeType, dtype: object
